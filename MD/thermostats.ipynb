# %% [markdown]
# ![Screenshot%20from%202023-01-23%2019-24-43.png](attachment:Screenshot%20from%202023-01-23%2019-24-43.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def GenerateCrystal(N):
    return np.array([np.array([i,j,k]) for i in range(N) for j in range(N) for k in range(N)])

def initializeMomenta(xstal, p0):
    p=dict()
    for i,particle in enumerate(xstal):
        p[i] = np.random.normal(size=3)
    return p

# %%
xstal = GenerateCrystal(10)
xstal.shape
# Out:
# (1000, 3)

# %%
gamma = .1
kb = 1
T = 2
dt = .1
m=1
def force(xstal, i, eps = 1, sigma = 1):
    force = 0
    for  in xstal:
        if part2 != particle: 
            force += - 24*eps*(-2*(sigma/r)**12 + (sigma/r)**6)*(1/r)
    return force

def run_(xstal, nsteps):
    p = initializeMomenta(xstal, 1)
    for i,particle in enumerate(xstal):
        p[i] = np.exp(-gamma*dt/2)*p[i] + np.sqrt(m*kb*T*(1-np.exp(-gamma*dt)))*np.random.normal()
        p[i] += force(xstal,i)/2*dt
        particle += p[i]/m*dt
        p[i] += force(particle)/2*dt
        p[i] = np.exp(-gamma*dt/2)*p[i] + np.sqrt(m*kb*T*(1-np.exp(-gamma*dt)))*np.random.normal()

# %%
run_(GenerateCrystal(2),100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 run_(GenerateCrystal(2),100)
#
# Cell In [8], line 17, in run_(xstal, nsteps)
#      15 for i,particle in enumerate(xstal):
#      16     p[i] = np.exp(-gamma*dt/2)*p[i] + np.sqrt(m*kb*T*(1-np.exp(-gamma*dt)))*np.random.normal()
# ---> 17     p[i] += force(xstal,particle)/2*dt
#      18     particle += p[i]/m*dt
#      19     p[i] += force(particle)/2*dt
#
# Cell In [8], line 9, in force(xstal, particle, eps, sigma)
#       7 force = 0
#       8 for part2 in xstal:
# ----> 9     if part2 != particle:
#      10         force += - 24*eps*(-2*(sigma/r)**12 + (sigma/r)**6)*(1/r)
#      11 return force
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# ![Screenshot%20from%202023-01-23%2019-25-22.png](attachment:Screenshot%20from%202023-01-23%2019-25-22.png)
